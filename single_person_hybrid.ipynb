# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape
from keras.utils import to_categorical
from keras import regularizers
import matplotlib.pyplot as plt

# %%
X_test = np.load("Data/X_test.npy")
y_test = np.load("Data/y_test.npy")
person_train_valid = np.load("Data/person_train_valid.npy")
X_train_valid = np.load("Data/X_train_valid.npy")
y_train_valid = np.load("Data/y_train_valid.npy")
person_test = np.load("Data/person_test.npy")

# %%
def train_data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:800]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    print('Shape of Y:',total_y.shape)
    return total_X,total_y


def test_data_prep(X):
    
    total_X = None
    
    
    # Trimming the data (sample,22,1000) -> (sample,22,800)
    X = X[:,:,0:800]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,800) -> (sample,22,800/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, 2), axis=3)
    
    
    total_X = X_max
    print('Shape of X after maxpooling:',total_X.shape)
    
    return total_X

# %%
person1_mask = (person_train_valid == 1).flatten()
X_train_valid_p1 = X_train_valid[person1_mask]
y_train_valid_p1 = y_train_valid[person1_mask]

# %%
y_train_valid_p1 -= 769
y_test -= 769

## Visualizing the data

ch_data = X_train_valid_p1[:,8,:]


class_0_ind = np.where(y_train_valid_p1 == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)


class_1_ind = np.where(y_train_valid_p1 == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid_p1 == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid_p1 == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)


plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])

# %%
## Preprocessing the dataset

X_train_valid_prep,y_train_valid_prep = train_data_prep(X_train_valid_p1,y_train_valid_p1,2,2,True)
X_test_prep = test_data_prep(X_test)
# Out:
# Shape of X after trimming: (236, 22, 800)
# Shape of X after maxpooling: (236, 22, 400)
# Shape of X after averaging+noise and concatenating: (472, 22, 400)
# Shape of X after subsampling and concatenating: (944, 22, 400)
# Shape of Y: (944,)
# Shape of X after trimming: (443, 22, 800)
# Shape of X after maxpooling: (443, 22, 400)

# %%
# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(944, 100, replace=False)
ind_train = np.array(list(set(range(944)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid] 
(y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (844, 22, 400)
# Shape of validation set: (100, 22, 400)
# Shape of training labels: (844,)
# Shape of validation labels: (100,)
# Shape of training labels after categorical conversion: (844, 4)
# Shape of validation labels after categorical conversion: (100, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (844, 22, 400, 1)
# Shape of validation set after adding width info: (100, 22, 400, 1)
# Shape of test set after adding width info: (443, 22, 400, 1)
# Shape of training set after dimension reshaping: (844, 400, 1, 22)
# Shape of validation set after dimension reshaping: (100, 400, 1, 22)
# Shape of test set after dimension reshaping: (443, 400, 1, 22)

# %%
hybrid_cnn_lstm_model2 = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model2.add(Conv2D(filters=25, kernel_size=(5,5), kernel_regularizer=regularizers.L2(1e-3),
                                  padding='same', activation='elu', input_shape=(400,1,22)))
hybrid_cnn_lstm_model2.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model2.add(BatchNormalization())
hybrid_cnn_lstm_model2.add(Dropout(0.4))

# Conv. block 2
hybrid_cnn_lstm_model2.add(Conv2D(filters=50, kernel_size=(5,5), kernel_regularizer=regularizers.L2(1e-3),
                                  padding='same', activation='elu'))
hybrid_cnn_lstm_model2.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model2.add(BatchNormalization())
hybrid_cnn_lstm_model2.add(Dropout(0.4))

# Conv. block 3
hybrid_cnn_lstm_model2.add(Conv2D(filters=100, kernel_size=(5,5), kernel_regularizer=regularizers.L2(1e-3),
                                  padding='same', activation='elu'))
hybrid_cnn_lstm_model2.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model2.add(BatchNormalization())
hybrid_cnn_lstm_model2.add(Dropout(0.4))

# Conv. block 4
hybrid_cnn_lstm_model2.add(Conv2D(filters=200, kernel_size=(5,5), kernel_regularizer=regularizers.L2(1e-3),
                                  padding='same', activation='elu'))
hybrid_cnn_lstm_model2.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model2.add(BatchNormalization())
hybrid_cnn_lstm_model2.add(Dropout(0.4))

# FC+LSTM layers
hybrid_cnn_lstm_model2.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_lstm_model2.add(Dense((40))) # FC layer with 100 units
hybrid_cnn_lstm_model2.add(Reshape((40,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_lstm_model2.add(LSTM(10, dropout=0.4, recurrent_dropout=0.1, input_shape=(40,1), return_sequences=False))

# Output layer with Softmax activation 
hybrid_cnn_lstm_model2.add(Dense(4, kernel_regularizer=regularizers.L2(1e-3), activation='softmax')) # Output FC layer with softmax activation

# Printing the model summary
hybrid_cnn_lstm_model2.summary()
# Out:
# WARNING:tensorflow:From C:\Users\eliu0\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\eliu0\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 400, 1, 25)        13775
#
#  max_pooling2d (MaxPooling2  (None, 134, 1, 25)        0
#  D)
#
#  batch_normalization (Batch  (None, 134, 1, 25)        100
#  Normalization)
#
#  dropout (Dropout)           (None, 134, 1, 25)        0
#
#  conv2d_1 (Conv2D)           (None, 134, 1, 50)        31300
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 1, 50)         0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 45, 1, 50)         200
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 45, 1, 50)         0
#
#  conv2d_2 (Conv2D)           (None, 45, 1, 100)        125100
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 1, 100)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 15, 1, 100)        400
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 15, 1, 100)        0
#
#  conv2d_3 (Conv2D)           (None, 15, 1, 200)        500200
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 1, 200)         0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 5, 1, 200)         800
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 5, 1, 200)         0
#
#  flatten (Flatten)           (None, 1000)              0
#
#  dense (Dense)               (None, 40)                40040
#
#  reshape (Reshape)           (None, 40, 1)             0
#
#  lstm (LSTM)                 (None, 10)                480
#
#  dense_1 (Dense)             (None, 4)                 44
#
# =================================================================
# Total params: 712439 (2.72 MB)
# Trainable params: 711689 (2.71 MB)
# Non-trainable params: 750 (2.93 KB)
# _________________________________________________________________

# %%
learning_rate = 1e-3
epochs = 100
hybrid_cnn_lstm_optimizer = keras.optimizers.Adam(learning_rate = learning_rate)

# %%
callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# Compiling the model
hybrid_cnn_lstm_model2.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_lstm_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results2 = hybrid_cnn_lstm_model2.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             callbacks=[callback],
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\eliu0\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\eliu0\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 14/14 [==============================] - 11s 178ms/step - loss: 1.5701 - accuracy: 0.2678 - val_loss: 1.5005 - val_accuracy: 0.2300
# Epoch 2/100
# 14/14 [==============================] - 2s 110ms/step - loss: 1.4578 - accuracy: 0.2844 - val_loss: 1.4482 - val_accuracy: 0.2500
# Epoch 3/100
# 14/14 [==============================] - 1s 107ms/step - loss: 1.3958 - accuracy: 0.3732 - val_loss: 1.4348 - val_accuracy: 0.3200
# Epoch 4/100
# 14/14 [==============================] - 1s 95ms/step - loss: 1.3694 - accuracy: 0.3685 - val_loss: 1.4142 - val_accuracy: 0.3600
# Epoch 5/100
# 14/14 [==============================] - 1s 95ms/step - loss: 1.3322 - accuracy: 0.4005 - val_loss: 1.3745 - val_accuracy: 0.3900
# Epoch 6/100
# 14/14 [==============================] - 1s 95ms/step - loss: 1.3175 - accuracy: 0.4100 - val_loss: 1.3217 - val_accuracy: 0.4700
# Epoch 7/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.2733 - accuracy: 0.4301 - val_loss: 1.2487 - val_accuracy: 0.4700
# Epoch 8/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.2250 - accuracy: 0.4538 - val_loss: 1.1922 - val_accuracy: 0.5300
# Epoch 9/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.2069 - accuracy: 0.4573 - val_loss: 1.0741 - val_accuracy: 0.5800
# Epoch 10/100
# 14/14 [==============================] - 1s 93ms/step - loss: 1.1917 - accuracy: 0.4739 - val_loss: 1.0078 - val_accuracy: 0.6500
# Epoch 11/100
# 14/14 [==============================] - 1s 94ms/step - loss: 1.1429 - accuracy: 0.5166 - val_loss: 0.9995 - val_accuracy: 0.6700
# Epoch 12/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.1042 - accuracy: 0.5308 - val_loss: 0.9553 - val_accuracy: 0.6600
# Epoch 13/100
# 14/14 [==============================] - 1s 95ms/step - loss: 1.0696 - accuracy: 0.5521 - val_loss: 0.8969 - val_accuracy: 0.6900
# Epoch 14/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.0539 - accuracy: 0.5735 - val_loss: 0.8521 - val_accuracy: 0.6800
# Epoch 15/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.0652 - accuracy: 0.5569 - val_loss: 0.7951 - val_accuracy: 0.7600
# Epoch 16/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.9926 - accuracy: 0.5806 - val_loss: 0.8033 - val_accuracy: 0.7600
# Epoch 17/100
# 14/14 [==============================] - 1s 96ms/step - loss: 1.0174 - accuracy: 0.5936 - val_loss: 0.8101 - val_accuracy: 0.7400
# Epoch 18/100
# 14/14 [==============================] - 2s 112ms/step - loss: 1.0042 - accuracy: 0.6102 - val_loss: 0.7456 - val_accuracy: 0.7400
# Epoch 19/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.9378 - accuracy: 0.6161 - val_loss: 0.7413 - val_accuracy: 0.7300
# Epoch 20/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.8928 - accuracy: 0.6765 - val_loss: 0.7503 - val_accuracy: 0.7500
# Epoch 21/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.8406 - accuracy: 0.6836 - val_loss: 0.6667 - val_accuracy: 0.8100
# Epoch 22/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.8116 - accuracy: 0.7097 - val_loss: 0.7172 - val_accuracy: 0.6800
# Epoch 23/100
# 14/14 [==============================] - 1s 93ms/step - loss: 0.8369 - accuracy: 0.6730 - val_loss: 0.6163 - val_accuracy: 0.8200
# Epoch 24/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.8447 - accuracy: 0.6671 - val_loss: 0.6816 - val_accuracy: 0.8000
# Epoch 25/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.8267 - accuracy: 0.6825 - val_loss: 0.6221 - val_accuracy: 0.7600
# Epoch 26/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.7821 - accuracy: 0.7002 - val_loss: 0.6257 - val_accuracy: 0.7900
# Epoch 27/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.7887 - accuracy: 0.7026 - val_loss: 0.5867 - val_accuracy: 0.8300
# Epoch 28/100
# 14/14 [==============================] - 1s 104ms/step - loss: 0.7547 - accuracy: 0.6884 - val_loss: 0.5414 - val_accuracy: 0.8300
# Epoch 29/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.7378 - accuracy: 0.6896 - val_loss: 0.5426 - val_accuracy: 0.8700
# Epoch 30/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.7693 - accuracy: 0.7002 - val_loss: 0.5461 - val_accuracy: 0.7700
# Epoch 31/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.7499 - accuracy: 0.7346 - val_loss: 0.5085 - val_accuracy: 0.8300
# Epoch 32/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.6691 - accuracy: 0.7441 - val_loss: 0.5136 - val_accuracy: 0.8000
# Epoch 33/100
# 14/14 [==============================] - 1s 105ms/step - loss: 0.7236 - accuracy: 0.7322 - val_loss: 0.5092 - val_accuracy: 0.8000
# Epoch 34/100
# 14/14 [==============================] - 1s 106ms/step - loss: 0.7133 - accuracy: 0.7701 - val_loss: 0.5387 - val_accuracy: 0.8300
# Epoch 35/100
# 14/14 [==============================] - 2s 111ms/step - loss: 0.6613 - accuracy: 0.7666 - val_loss: 0.5821 - val_accuracy: 0.7200
# Epoch 36/100
# 14/14 [==============================] - 1s 108ms/step - loss: 0.6359 - accuracy: 0.7737 - val_loss: 0.4970 - val_accuracy: 0.8200
# Epoch 37/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.6412 - accuracy: 0.7915 - val_loss: 0.4947 - val_accuracy: 0.8500
# Epoch 38/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.6891 - accuracy: 0.7595 - val_loss: 0.5229 - val_accuracy: 0.7800
# Epoch 39/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.6399 - accuracy: 0.7784 - val_loss: 0.4689 - val_accuracy: 0.8600
# Epoch 40/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.6754 - accuracy: 0.7844 - val_loss: 0.4799 - val_accuracy: 0.8100
# Epoch 41/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.6432 - accuracy: 0.7938 - val_loss: 0.4992 - val_accuracy: 0.8400
# Epoch 42/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.6188 - accuracy: 0.8069 - val_loss: 0.4497 - val_accuracy: 0.8800
# Epoch 43/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.6126 - accuracy: 0.8140 - val_loss: 0.4489 - val_accuracy: 0.8900
# Epoch 44/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.5821 - accuracy: 0.8175 - val_loss: 0.4569 - val_accuracy: 0.9000
# Epoch 45/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.5771 - accuracy: 0.8341 - val_loss: 0.4518 - val_accuracy: 0.8800
# Epoch 46/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.5542 - accuracy: 0.8412 - val_loss: 0.4285 - val_accuracy: 0.9000
# Epoch 47/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.5468 - accuracy: 0.8578 - val_loss: 0.4796 - val_accuracy: 0.8300
# Epoch 48/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.5935 - accuracy: 0.8258 - val_loss: 0.4317 - val_accuracy: 0.8800
# Epoch 49/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.5422 - accuracy: 0.8602 - val_loss: 0.4592 - val_accuracy: 0.8700
# Epoch 50/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.5353 - accuracy: 0.8566 - val_loss: 0.4432 - val_accuracy: 0.8800
# Epoch 51/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.5521 - accuracy: 0.8566 - val_loss: 0.4778 - val_accuracy: 0.8900
# Epoch 52/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.5655 - accuracy: 0.8661 - val_loss: 0.4711 - val_accuracy: 0.9000
# Epoch 53/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.5194 - accuracy: 0.8744 - val_loss: 0.3898 - val_accuracy: 0.9200
# Epoch 54/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.5319 - accuracy: 0.8839 - val_loss: 0.3674 - val_accuracy: 0.9400
# Epoch 55/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.5418 - accuracy: 0.8637 - val_loss: 0.3858 - val_accuracy: 0.9000
# Epoch 56/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.5227 - accuracy: 0.8673 - val_loss: 0.3484 - val_accuracy: 0.9300
# Epoch 57/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.4643 - accuracy: 0.9123 - val_loss: 0.3530 - val_accuracy: 0.9200
# Epoch 58/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.4501 - accuracy: 0.9123 - val_loss: 0.3281 - val_accuracy: 0.9500
# Epoch 59/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.4364 - accuracy: 0.9135 - val_loss: 0.3160 - val_accuracy: 0.9800
# Epoch 60/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.4341 - accuracy: 0.9182 - val_loss: 0.2854 - val_accuracy: 0.9800
# Epoch 61/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.4414 - accuracy: 0.9206 - val_loss: 0.2821 - val_accuracy: 0.9700
# Epoch 62/100
# 14/14 [==============================] - 1s 102ms/step - loss: 0.4218 - accuracy: 0.9218 - val_loss: 0.2772 - val_accuracy: 0.9800
# Epoch 63/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.4785 - accuracy: 0.9206 - val_loss: 0.2631 - val_accuracy: 0.9900
# Epoch 64/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.4715 - accuracy: 0.9052 - val_loss: 0.2673 - val_accuracy: 0.9900
# Epoch 65/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.4437 - accuracy: 0.9123 - val_loss: 0.2613 - val_accuracy: 0.9800
# Epoch 66/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.4202 - accuracy: 0.9135 - val_loss: 0.2650 - val_accuracy: 0.9700
# Epoch 67/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.4478 - accuracy: 0.9242 - val_loss: 0.2598 - val_accuracy: 0.9800
# Epoch 68/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.4563 - accuracy: 0.9182 - val_loss: 0.2629 - val_accuracy: 0.9800
# Epoch 69/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.4358 - accuracy: 0.9147 - val_loss: 0.2513 - val_accuracy: 1.0000
# Epoch 70/100
# 14/14 [==============================] - 1s 99ms/step - loss: 0.4148 - accuracy: 0.9265 - val_loss: 0.2529 - val_accuracy: 1.0000
# Epoch 71/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.3835 - accuracy: 0.9396 - val_loss: 0.2304 - val_accuracy: 1.0000
# Epoch 72/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.3584 - accuracy: 0.9502 - val_loss: 0.2273 - val_accuracy: 1.0000
# Epoch 73/100
# 14/14 [==============================] - 1s 100ms/step - loss: 0.3395 - accuracy: 0.9668 - val_loss: 0.2264 - val_accuracy: 1.0000
# Epoch 74/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.3426 - accuracy: 0.9585 - val_loss: 0.2219 - val_accuracy: 1.0000
# Epoch 75/100
# 14/14 [==============================] - 1s 99ms/step - loss: 0.3463 - accuracy: 0.9562 - val_loss: 0.2206 - val_accuracy: 1.0000
# Epoch 76/100
# 14/14 [==============================] - 1s 107ms/step - loss: 0.3555 - accuracy: 0.9550 - val_loss: 0.2256 - val_accuracy: 1.0000
# Epoch 77/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.3537 - accuracy: 0.9597 - val_loss: 0.2154 - val_accuracy: 1.0000
# Epoch 78/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.3292 - accuracy: 0.9621 - val_loss: 0.2148 - val_accuracy: 1.0000
# Epoch 79/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.2935 - accuracy: 0.9763 - val_loss: 0.2155 - val_accuracy: 1.0000
# Epoch 80/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.3386 - accuracy: 0.9538 - val_loss: 0.2154 - val_accuracy: 1.0000
# Epoch 81/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.3539 - accuracy: 0.9514 - val_loss: 0.2604 - val_accuracy: 0.9900
# Epoch 82/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.4160 - accuracy: 0.9301 - val_loss: 0.2297 - val_accuracy: 1.0000
# Epoch 83/100
# 14/14 [==============================] - 1s 95ms/step - loss: 0.3846 - accuracy: 0.9372 - val_loss: 0.2292 - val_accuracy: 1.0000
# Epoch 84/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.4185 - accuracy: 0.9289 - val_loss: 0.2402 - val_accuracy: 1.0000
# Epoch 85/100
# 14/14 [==============================] - 1s 97ms/step - loss: 0.4009 - accuracy: 0.9348 - val_loss: 0.2408 - val_accuracy: 0.9900
# Epoch 86/100
# 14/14 [==============================] - 1s 96ms/step - loss: 0.3673 - accuracy: 0.9526 - val_loss: 0.2361 - val_accuracy: 0.9900
# Epoch 87/100
# 14/14 [==============================] - 1s 94ms/step - loss: 0.3382 - accuracy: 0.9668 - val_loss: 0.2260 - val_accuracy: 1.0000
# Epoch 88/100
# 14/14 [==============================] - 1s 101ms/step - loss: 0.3413 - accuracy: 0.9562 - val_loss: 0.2290 - val_accuracy: 1.0000
# Epoch 89/100
# 14/14 [==============================] - 1s 98ms/step - loss: 0.3433 - accuracy: 0.9645 - val_loss: 0.2301 - val_accuracy: 0.9900

# %%
# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results2.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results2.history['val_accuracy'])
plt.title('Hybrid CNN-LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results2.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results2.history['val_loss'],'o')
plt.title('Hybrid CNN-LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
hybrid_cnn_lstm_score2 = hybrid_cnn_lstm_model2.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-LSTM model:',hybrid_cnn_lstm_score2[1])
# Out:
# Test accuracy of the hybrid CNN-LSTM model: 0.3679458200931549

# %%
p1_mask = (person_test == 1).flatten()
x_test = x_test[p1_mask]
y_test = y_test[p1_mask]

print(x_test.shape)
print(y_test.shape)
# Out:
# (50, 400, 1, 22)
# (50, 4)

# %%
hybrid_cnn_lstm_score2 = hybrid_cnn_lstm_model2.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-LSTM model, single person:',hybrid_cnn_lstm_score2[1])
# Out:
# Test accuracy of the hybrid CNN-LSTM model, single person: 0.3400000035762787
